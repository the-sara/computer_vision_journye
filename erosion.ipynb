# %%
#erosion:is to erode the outlines

# %%
import cv2
import matplotlib.pyplot as plt 
img=cv2.imread("daizy2.jpg")
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img)

# %%
erode_img=cv2.erode(img,(11,11))
plt.imshow(erode_img)
