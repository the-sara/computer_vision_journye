# %%
import cv2
import matplotlib.pyplot as plt 
img=cv2.imread("daizy2.jpg")
plt.imshow(img)

# %%
edges1=cv2.Canny(img,50,100)
plt.imshow(edges1)

# %%
edges1=cv2.Canny(img,30,200)
plt.imshow(edges1)
