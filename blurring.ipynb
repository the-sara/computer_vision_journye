# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("daizy2.jpg")
plt.imshow(img)

# %%
#blurring the image to smoth 
img_blurred1=cv2.GaussianBlur(img,(5,5),0)
plt.imshow(img_blurred1)

# %%
#blurring the image to smoth 
img_blurred2=cv2.GaussianBlur(img,(9,9),0)
plt.imshow(img_blurred2)
