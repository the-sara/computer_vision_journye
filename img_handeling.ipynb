# %%
# this is how we do image handeling in opencv :

# %%
import cv2
import matplotlib.pyplot as plt
# reading an image:
img=cv2.imread("daizy2.jpg")

# %%
#displaying the img :
cv2.imshow("img window",img)
plt.imshow(img)
